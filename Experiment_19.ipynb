# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# -----------------------------
# Sample Bank Loan Dataset
# -----------------------------
data = {
    'Gender': ['Male', 'Female', 'Male', 'Male', 'Female',
               'Male', 'Female', 'Male', 'Female', 'Male'],

    'Married': ['Yes', 'No', 'Yes', 'Yes', 'No',
                'Yes', 'No', 'Yes', 'Yes', 'No'],

    'Education': ['Graduate', 'Graduate', 'Not Graduate', 'Graduate', 'Graduate',
                  'Not Graduate', 'Graduate', 'Graduate', 'Not Graduate', 'Graduate'],

    'ApplicantIncome': [5000, 3000, 2500, 6000, 3500,
                        2000, 4500, 8000, 2200, 7000],

    'LoanAmount': [150, 100, 90, 200, 120,
                   80, 130, 250, 85, 220],

    'Credit_History': [1, 1, 0, 1, 1,
                       0, 1, 1, 0, 1],

    'Loan_Status': ['Y', 'Y', 'N', 'Y', 'Y',
                    'N', 'Y', 'Y', 'N', 'Y']
}

# Create DataFrame
df = pd.DataFrame(data)

print("Bank Loan Dataset:\n")
print(df)

# -----------------------------
# Encode Categorical Variables
# -----------------------------
gender_encoder = LabelEncoder()
married_encoder = LabelEncoder()
education_encoder = LabelEncoder()
loan_encoder = LabelEncoder()

df['Gender'] = gender_encoder.fit_transform(df['Gender'])
df['Married'] = married_encoder.fit_transform(df['Married'])
df['Education'] = education_encoder.fit_transform(df['Education'])
df['Loan_Status'] = loan_encoder.fit_transform(df['Loan_Status'])

# -----------------------------
# Features and Target
# -----------------------------
X = df.drop('Loan_Status', axis=1)
y = df['Loan_Status']

# -----------------------------
# Split Dataset
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# -----------------------------
# Train Naive Bayes Model
# -----------------------------
model = GaussianNB()
model.fit(X_train, y_train)

# -----------------------------
# Predict Test Data
# -----------------------------
y_pred = model.predict(X_test)

print("\nPredicted Values:")
print(y_pred)

print("\nActual Values:")
print(y_test.values)

print("\nAccuracy:")
print(accuracy_score(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

# -----------------------------
# Predict New Applicant
# -----------------------------
new_applicant = pd.DataFrame({
    'Gender': [gender_encoder.transform(['Male'])[0]],
    'Married': [married_encoder.transform(['Yes'])[0]],
    'Education': [education_encoder.transform(['Graduate'])[0]],
    'ApplicantIncome': [5500],
    'LoanAmount': [160],
    'Credit_History': [1]
})

prediction = model.predict(new_applicant)

print("\nNew Applicant Loan Status:")

if prediction[0] == loan_encoder.transform(['Y'])[0]:
    print("Approved")
else:
    print("Not Approved")
# Out:
# Bank Loan Dataset:
#
#    Gender Married     Education  ApplicantIncome  LoanAmount  Credit_History  \
# 0    Male     Yes      Graduate             5000         150               1
# 1  Female      No      Graduate             3000         100               1
# 2    Male     Yes  Not Graduate             2500          90               0
# 3    Male     Yes      Graduate             6000         200               1
# 4  Female      No      Graduate             3500         120               1
# 5    Male     Yes  Not Graduate             2000          80               0
# 6  Female      No      Graduate             4500         130               1
# 7    Male     Yes      Graduate             8000         250               1
# 8  Female     Yes  Not Graduate             2200          85               0
# 9    Male      No      Graduate             7000         220               1
#
#   Loan_Status
# 0           Y
# 1           Y
# 2           N
# 3           Y
# 4           Y
# ...
