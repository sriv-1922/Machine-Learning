# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Create dataset
data = {
    "PreviousAttendance": ["High","High","Low","Medium","High","Low","Medium","High"],
    "Distance": ["Near","Far","Far","Near","Near","Far","Near","Far"],
    "Weather": ["Sunny","Rainy","Rainy","Sunny","Cloudy","Rainy","Sunny","Cloudy"],
    "Day": ["Weekday","Weekday","Weekend","Weekday","Weekend","Weekday","Weekend","Weekday"],
    "Status": ["Present","Absent","Absent","Present","Present","Absent","Present","Absent"]
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)

# Convert categorical values into numbers
encoder = LabelEncoder()

for column in df.columns:
    df[column] = encoder.fit_transform(df[column])

# Features and Target
X = df.drop("Status", axis=1)
y = df["Status"]

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Train model
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

print("\nPredicted Values:")
print(y_pred)

print("\nActual Values:")
print(y_test.values)

print("\nAccuracy:")
print(accuracy_score(y_test, y_pred))
# Out:
# Dataset:
#   PreviousAttendance Distance Weather      Day   Status
# 0               High     Near   Sunny  Weekday  Present
# 1               High      Far   Rainy  Weekday   Absent
# 2                Low      Far   Rainy  Weekend   Absent
# 3             Medium     Near   Sunny  Weekday  Present
# 4               High     Near  Cloudy  Weekend  Present
# 5                Low      Far   Rainy  Weekday   Absent
# 6             Medium     Near   Sunny  Weekend  Present
# 7               High      Far  Cloudy  Weekday   Absent
#
# Predicted Values:
# [0 0]
#
# Actual Values:
# [0 0]
#
# Accuracy:
# 1.0
